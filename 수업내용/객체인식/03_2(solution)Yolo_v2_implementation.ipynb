# %% [markdown]
# # Yolo_v2_implementation

# %% [markdown]
# ## darknet-19

# %%
# import tensorflow as tf
# from tensorflow.keras import layers
import torch
from torch import nn
from torchinfo import summary

# %%
def conv_block(x, filters, kernel_size):
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='linear')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    return x

class basic_conv(nn.Module):
    def __init__(self, in_channels, output_channels, kernel_size, stride=1, output=False):
        super.__init__()
        if output:
            self.conv= nn.Sequential(
                nn.Conv2d(in_channels, output_channels, kernel_size, stride, padding = (kernel_size - 1) // 2)
                
            )
        else:
            self.conv=nn.Sequential(
                nn.Conv2d(in_channels, output_channels, kernel_size, stride, padding = (kernel_size - 1) // 2),
                nn.BatchNorm2d(output_channels),
                nn.LeakyReLU(0.1, inplace=True)
            )
    def forward(self, x):
        return self.conv(x)
    
class basic_yolo_block(nn.Module):
    def __init__(self, in_channels, output_channels, double):
        super.__init__()
        self.block= nn.Sequential(
            basic_conv(in_channels, output_channels, 3),
            basic_conv(output_channels, output_channels//2, 1),
            basic_conv(output_channels//2, output_channels, 3),
            basic_conv(output_channels, output_channels//2, 1),
            basic_conv(output_channels//2, output_channels, 3)
        )

class Yolo_v2(nn.Module):
    def __init__(self, anchors = [(1.3221, 1.73145), (3.19275, 4.00944), (5.05587, 8.09892), (9.47112, 4.84053),(11.2364, 10.0071)], num_classes = 20):
        super.__init__()

        self.num_class= num_classes
        self.anchors= anchors

        self.first_conv_block= nn.Sequential(
            basic_conv(3, 32, 3),
            nn.MaxPool2d(2),
            basic_conv(32, 64, 3),
            nn.MaxPool2d(2)
        )

        self.second_conv_block= nn.Sequential(
            basic_conv(64, 128, 3),
            basic_conv(128, 64, 1),
            basic_conv(64, 128, 3),
            nn.MaxPool2d(2)
        )

        self.third_conv_block= nn.Sequential(
            basic_conv
        )
def darknet19(input_shape=(224, 224, 3), num_classes=1000):
    inputs = tf.keras.Input(shape=input_shape)

    # Block 1
    x = conv_block(inputs, 32, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 2
    x = conv_block(x, 64, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 3
    x = conv_block(x, 128, 3)
    x = conv_block(x, 64, 1)
    x = conv_block(x, 128, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 4
    x = conv_block(x, 256, 3)
    x = conv_block(x, 128, 1)
    x = conv_block(x, 256, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 5
    x = conv_block(x, 512, 3)
    x = conv_block(x, 256, 1)
    x = conv_block(x, 512, 3)
    x = conv_block(x, 256, 1)
    x = conv_block(x, 512, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 6
    x = conv_block(x, 1024, 3)
    x = conv_block(x, 512, 1)
    x = conv_block(x, 1024, 3)
    x = conv_block(x, 512, 1)
    x = conv_block(x, 1024, 3)

    # Additional 1x1 conv Layer
    x = conv_block(x, 1000, 1)

    # Output
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
darknet_19 = darknet19()
darknet_19.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 224, 224, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 56, 56, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 64)        8256
#
#  batch_normalization_3 (Batc  (None, 56, 56, 64)       256
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 56, 56, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 56, 56, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 256)       295168
#
#  batch_normalization_5 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 28, 28, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 128)       32896
#
#  batch_normalization_6 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 256)       295168
#
#  batch_normalization_7 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 28, 28, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 512)       1180160
#
#  batch_normalization_8 (Batc  (None, 14, 14, 512)      2048
#  hNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 14, 14, 512)       0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 256)       131328
#
#  batch_normalization_9 (Batc  (None, 14, 14, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 14, 14, 256)       0
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       1180160
#
#  batch_normalization_10 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 14, 14, 512)       0
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 256)       131328
#
#  batch_normalization_11 (Bat  (None, 14, 14, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 14, 14, 256)       0
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       1180160
#
#  batch_normalization_12 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 14, 14, 512)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 7, 7, 1024)        4719616
#
#  batch_normalization_13 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 512)         524800
#
#  batch_normalization_14 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 7, 7, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 7, 7, 1024)        4719616
#
#  batch_normalization_15 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  conv2d_16 (Conv2D)          (None, 7, 7, 512)         524800
#
#  batch_normalization_16 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 7, 7, 512)         0
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 1024)        4719616
#
#  batch_normalization_17 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  conv2d_18 (Conv2D)          (None, 7, 7, 1000)        1025000
#
#  batch_normalization_18 (Bat  (None, 7, 7, 1000)       4000
#  chNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 7, 7, 1000)        0
#
#  global_average_pooling2d (G  (None, 1000)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)              1001000
#
# =================================================================
# Total params: 21,868,976
# Trainable params: 21,852,576
# Non-trainable params: 16,400
# _________________________________________________________________

# %%
darknet_19 = darknet19((448, 448, 3))
darknet_19.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 448, 448, 3)]     0
#
#  conv2d_38 (Conv2D)          (None, 448, 448, 32)      896
#
#  batch_normalization_38 (Bat  (None, 448, 448, 32)     128
#  chNormalization)
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 448, 448, 32)      0
#
#  max_pooling2d_10 (MaxPoolin  (None, 224, 224, 32)     0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 224, 224, 64)      18496
#
#  batch_normalization_39 (Bat  (None, 224, 224, 64)     256
#  chNormalization)
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 224, 224, 64)      0
#
#  max_pooling2d_11 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 112, 112, 128)     73856
#
#  batch_normalization_40 (Bat  (None, 112, 112, 128)    512
#  chNormalization)
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 112, 112, 128)     0
#
#  conv2d_41 (Conv2D)          (None, 112, 112, 64)      8256
#
#  batch_normalization_41 (Bat  (None, 112, 112, 64)     256
#  chNormalization)
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 112, 112, 64)      0
#
#  conv2d_42 (Conv2D)          (None, 112, 112, 128)     73856
#
#  batch_normalization_42 (Bat  (None, 112, 112, 128)    512
#  chNormalization)
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 112, 112, 128)     0
#
#  max_pooling2d_12 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 56, 56, 256)       295168
#
#  batch_normalization_43 (Bat  (None, 56, 56, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 56, 56, 256)       0
#
#  conv2d_44 (Conv2D)          (None, 56, 56, 128)       32896
#
#  batch_normalization_44 (Bat  (None, 56, 56, 128)      512
#  chNormalization)
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 56, 56, 128)       0
#
#  conv2d_45 (Conv2D)          (None, 56, 56, 256)       295168
#
#  batch_normalization_45 (Bat  (None, 56, 56, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_45 (LeakyReLU)  (None, 56, 56, 256)       0
#
#  max_pooling2d_13 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  batch_normalization_46 (Bat  (None, 28, 28, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_46 (LeakyReLU)  (None, 28, 28, 512)       0
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 256)       131328
#
#  batch_normalization_47 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_47 (LeakyReLU)  (None, 28, 28, 256)       0
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  batch_normalization_48 (Bat  (None, 28, 28, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_48 (LeakyReLU)  (None, 28, 28, 512)       0
#
#  conv2d_49 (Conv2D)          (None, 28, 28, 256)       131328
#
#  batch_normalization_49 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_49 (LeakyReLU)  (None, 28, 28, 256)       0
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  batch_normalization_50 (Bat  (None, 28, 28, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_50 (LeakyReLU)  (None, 28, 28, 512)       0
#
#  max_pooling2d_14 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_51 (Conv2D)          (None, 14, 14, 1024)      4719616
#
#  batch_normalization_51 (Bat  (None, 14, 14, 1024)     4096
#  chNormalization)
#
#  leaky_re_lu_51 (LeakyReLU)  (None, 14, 14, 1024)      0
#
#  conv2d_52 (Conv2D)          (None, 14, 14, 512)       524800
#
#  batch_normalization_52 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_52 (LeakyReLU)  (None, 14, 14, 512)       0
#
#  conv2d_53 (Conv2D)          (None, 14, 14, 1024)      4719616
#
#  batch_normalization_53 (Bat  (None, 14, 14, 1024)     4096
#  chNormalization)
#
#  leaky_re_lu_53 (LeakyReLU)  (None, 14, 14, 1024)      0
#
#  conv2d_54 (Conv2D)          (None, 14, 14, 512)       524800
#
#  batch_normalization_54 (Bat  (None, 14, 14, 512)      2048
#  chNormalization)
#
#  leaky_re_lu_54 (LeakyReLU)  (None, 14, 14, 512)       0
#
#  conv2d_55 (Conv2D)          (None, 14, 14, 1024)      4719616
#
#  batch_normalization_55 (Bat  (None, 14, 14, 1024)     4096
#  chNormalization)
#
#  leaky_re_lu_55 (LeakyReLU)  (None, 14, 14, 1024)      0
#
#  conv2d_56 (Conv2D)          (None, 14, 14, 1000)      1025000
#
#  batch_normalization_56 (Bat  (None, 14, 14, 1000)     4000
#  chNormalization)
#
#  leaky_re_lu_56 (LeakyReLU)  (None, 14, 14, 1000)      0
#
#  global_average_pooling2d_2   (None, 1000)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1000)              1001000
#
# =================================================================
# Total params: 21,868,976
# Trainable params: 21,852,576
# Non-trainable params: 16,400
# _________________________________________________________________

# %% [markdown]
# ## YOLO V2

# %%
def conv_block(x, filters, kernel_size):
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='linear')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    return x

def yolo_v2(input_shape=(416, 416, 3), num_class=20, bbox_per_cell=5):
    inputs = tf.keras.Input(shape=input_shape)

    # Block 1
    x = conv_block(inputs, 32, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 2
    x = conv_block(x, 64, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 3
    x = conv_block(x, 128, 3)
    x = conv_block(x, 64, 1)
    x = conv_block(x, 128, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 4
    x = conv_block(x, 256, 3)
    x = conv_block(x, 128, 1)
    x = conv_block(x, 256, 3)
    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 5
    x = conv_block(x, 512, 3)
    x = conv_block(x, 256, 1)
    x = conv_block(x, 512, 3)
    x = conv_block(x, 256, 1)
    x = conv_block(x, 512, 3) # 26 x 26 x 512

    # Fine Grained Features / 0~12 + 13~25
    ## method 1
    # x_1 = x[:, :13, :13, :] # batch x 13 x 13 x 512
    # x_2 = x[:, :13, 13:, :]
    # x_3 = x[:, 13:, :13, :]
    # x_4 = x[:, 13:, 13:, :]
    ## method 2
    x_1 = x[:, ::2, ::2, :]
    x_2 = x[:, ::2, 1::2, :]
    x_3 = x[:, 1::2, ::2, :]
    x_4 = x[:, 1::2, 1::2, :]
    fine_grained = tf.concat([x_1, x_2, x_3, x_4], axis = -1) # batch x 13 x 13 x 2048

    x = layers.MaxPooling2D(pool_size=2)(x)

    # Block 6
    x = conv_block(x, 1024, 3)
    x = conv_block(x, 512, 1)
    x = conv_block(x, 1024, 3)
    x = conv_block(x, 512, 1)
    x = conv_block(x, 1024, 3)
    x = conv_block(x, 1024, 3) # add
    x = conv_block(x, 1024, 3) # add

    x = tf.concat([x, fine_grained], axis = -1) # batch x 13 x 13 x 3072

    # Output
    x = conv_block(x, 1024, 3)
    outputs = conv_block(x, bbox_per_cell*(num_class+5), 1)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
yolo_v2 = yolo_v2()
yolo_v2.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv2d_79 (Conv2D)             (None, 416, 416, 32  896         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_79 (BatchN  (None, 416, 416, 32  128        ['conv2d_79[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_79 (LeakyReLU)     (None, 416, 416, 32  0           ['batch_normalization_79[0][0]']
#                                 )
#
#  max_pooling2d_20 (MaxPooling2D  (None, 208, 208, 32  0          ['leaky_re_lu_79[0][0]']
#  )                              )
#
#  conv2d_80 (Conv2D)             (None, 208, 208, 64  18496       ['max_pooling2d_20[0][0]']
#                                 )
#
#  batch_normalization_80 (BatchN  (None, 208, 208, 64  256        ['conv2d_80[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_80 (LeakyReLU)     (None, 208, 208, 64  0           ['batch_normalization_80[0][0]']
#                                 )
#
#  max_pooling2d_21 (MaxPooling2D  (None, 104, 104, 64  0          ['leaky_re_lu_80[0][0]']
#  )                              )
#
#  conv2d_81 (Conv2D)             (None, 104, 104, 12  73856       ['max_pooling2d_21[0][0]']
#                                 8)
#
#  batch_normalization_81 (BatchN  (None, 104, 104, 12  512        ['conv2d_81[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_81 (LeakyReLU)     (None, 104, 104, 12  0           ['batch_normalization_81[0][0]']
#                                 8)
#
#  conv2d_82 (Conv2D)             (None, 104, 104, 64  8256        ['leaky_re_lu_81[0][0]']
#                                 )
#
#  batch_normalization_82 (BatchN  (None, 104, 104, 64  256        ['conv2d_82[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_82 (LeakyReLU)     (None, 104, 104, 64  0           ['batch_normalization_82[0][0]']
#                                 )
#
#  conv2d_83 (Conv2D)             (None, 104, 104, 12  73856       ['leaky_re_lu_82[0][0]']
#                                 8)
#
#  batch_normalization_83 (BatchN  (None, 104, 104, 12  512        ['conv2d_83[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_83 (LeakyReLU)     (None, 104, 104, 12  0           ['batch_normalization_83[0][0]']
#                                 8)
#
#  max_pooling2d_22 (MaxPooling2D  (None, 52, 52, 128)  0          ['leaky_re_lu_83[0][0]']
#  )
#
#  conv2d_84 (Conv2D)             (None, 52, 52, 256)  295168      ['max_pooling2d_22[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 52, 52, 256)  1024       ['conv2d_84[0][0]']
#  ormalization)
#
#  leaky_re_lu_84 (LeakyReLU)     (None, 52, 52, 256)  0           ['batch_normalization_84[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 52, 52, 128)  32896       ['leaky_re_lu_84[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 52, 52, 128)  512        ['conv2d_85[0][0]']
#  ormalization)
#
#  leaky_re_lu_85 (LeakyReLU)     (None, 52, 52, 128)  0           ['batch_normalization_85[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 52, 52, 256)  295168      ['leaky_re_lu_85[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 52, 52, 256)  1024       ['conv2d_86[0][0]']
#  ormalization)
#
#  leaky_re_lu_86 (LeakyReLU)     (None, 52, 52, 256)  0           ['batch_normalization_86[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 26, 26, 256)  0          ['leaky_re_lu_86[0][0]']
#  )
#
#  conv2d_87 (Conv2D)             (None, 26, 26, 512)  1180160     ['max_pooling2d_23[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 26, 26, 512)  2048       ['conv2d_87[0][0]']
#  ormalization)
#
#  leaky_re_lu_87 (LeakyReLU)     (None, 26, 26, 512)  0           ['batch_normalization_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 26, 26, 256)  131328      ['leaky_re_lu_87[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 26, 26, 256)  1024       ['conv2d_88[0][0]']
#  ormalization)
#
#  leaky_re_lu_88 (LeakyReLU)     (None, 26, 26, 256)  0           ['batch_normalization_88[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 26, 26, 512)  1180160     ['leaky_re_lu_88[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 26, 26, 512)  2048       ['conv2d_89[0][0]']
#  ormalization)
#
#  leaky_re_lu_89 (LeakyReLU)     (None, 26, 26, 512)  0           ['batch_normalization_89[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 26, 26, 256)  131328      ['leaky_re_lu_89[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 26, 26, 256)  1024       ['conv2d_90[0][0]']
#  ormalization)
#
#  leaky_re_lu_90 (LeakyReLU)     (None, 26, 26, 256)  0           ['batch_normalization_90[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 26, 26, 512)  1180160     ['leaky_re_lu_90[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 26, 26, 512)  2048       ['conv2d_91[0][0]']
#  ormalization)
#
#  leaky_re_lu_91 (LeakyReLU)     (None, 26, 26, 512)  0           ['batch_normalization_91[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 13, 13, 512)  0          ['leaky_re_lu_91[0][0]']
#  )
#
#  conv2d_92 (Conv2D)             (None, 13, 13, 1024  4719616     ['max_pooling2d_24[0][0]']
#                                 )
#
#  batch_normalization_92 (BatchN  (None, 13, 13, 1024  4096       ['conv2d_92[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_92 (LeakyReLU)     (None, 13, 13, 1024  0           ['batch_normalization_92[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 13, 13, 512)  524800      ['leaky_re_lu_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 13, 13, 512)  2048       ['conv2d_93[0][0]']
#  ormalization)
#
#  leaky_re_lu_93 (LeakyReLU)     (None, 13, 13, 512)  0           ['batch_normalization_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 13, 13, 1024  4719616     ['leaky_re_lu_93[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 13, 13, 1024  4096       ['conv2d_94[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_94 (LeakyReLU)     (None, 13, 13, 1024  0           ['batch_normalization_94[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 13, 13, 512)  524800      ['leaky_re_lu_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 13, 13, 512)  2048       ['conv2d_95[0][0]']
#  ormalization)
#
#  leaky_re_lu_95 (LeakyReLU)     (None, 13, 13, 512)  0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 13, 13, 1024  4719616     ['leaky_re_lu_95[0][0]']
#                                 )
#
#  batch_normalization_96 (BatchN  (None, 13, 13, 1024  4096       ['conv2d_96[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_96 (LeakyReLU)     (None, 13, 13, 1024  0           ['batch_normalization_96[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 13, 13, 1024  9438208     ['leaky_re_lu_96[0][0]']
#                                 )
#
#  batch_normalization_97 (BatchN  (None, 13, 13, 1024  4096       ['conv2d_97[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_97 (LeakyReLU)     (None, 13, 13, 1024  0           ['batch_normalization_97[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 13, 13, 1024  9438208     ['leaky_re_lu_97[0][0]']
#                                 )
#
#  batch_normalization_98 (BatchN  (None, 13, 13, 1024  4096       ['conv2d_98[0][0]']
#  ormalization)                  )
#
#  tf.__operators__.getitem_4 (Sl  (None, 13, 13, 512)  0          ['leaky_re_lu_91[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  (None, 13, 13, 512)  0          ['leaky_re_lu_91[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_6 (Sl  (None, 13, 13, 512)  0          ['leaky_re_lu_91[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, 13, 13, 512)  0          ['leaky_re_lu_91[0][0]']
#  icingOpLambda)
#
#  leaky_re_lu_98 (LeakyReLU)     (None, 13, 13, 1024  0           ['batch_normalization_98[0][0]']
#                                 )
#
#  tf.concat_1 (TFOpLambda)       (None, 13, 13, 2048  0           ['tf.__operators__.getitem_4[0][0
#                                 )                                ]',
#                                                                   'tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_6[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  tf.concat_2 (TFOpLambda)       (None, 13, 13, 3072  0           ['leaky_re_lu_98[0][0]',
#                                 )                                 'tf.concat_1[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 13, 13, 1024  28312576    ['tf.concat_2[0][0]']
#                                 )
#
#  batch_normalization_99 (BatchN  (None, 13, 13, 1024  4096       ['conv2d_99[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_99 (LeakyReLU)     (None, 13, 13, 1024  0           ['batch_normalization_99[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 13, 13, 125)  128125      ['leaky_re_lu_99[0][0]']
#
#  batch_normalization_100 (Batch  (None, 13, 13, 125)  500        ['conv2d_100[0][0]']
#  Normalization)
#
#  leaky_re_lu_100 (LeakyReLU)    (None, 13, 13, 125)  0           ['batch_normalization_100[0][0]']
#
# ==================================================================================================
# Total params: 67,168,881
# Trainable params: 67,148,087
# Non-trainable params: 20,794
# __________________________________________________________________________________________________
